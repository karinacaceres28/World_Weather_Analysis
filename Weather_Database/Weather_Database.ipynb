# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 738

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]       
        city_current_description = city_weather['weather'][0]['description']
        
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_current_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | aasiaat
# Processing Record 2 of Set 1 | pemberton
# Processing Record 3 of Set 1 | poplar bluff
# Processing Record 4 of Set 1 | yar-sale
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | souillac
# Processing Record 7 of Set 1 | pechenga
# Processing Record 8 of Set 1 | hilo
# Processing Record 9 of Set 1 | ryotsu
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | hobart
# Processing Record 12 of Set 1 | phalodi
# Processing Record 13 of Set 1 | fioletovo
# Processing Record 14 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 15 of Set 1 | kapaa
# Processing Record 16 of Set 1 | slave lake
# Processing Record 17 of Set 1 | mataura
# Processing Record 18 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 19 of Set 1 | port lincoln
# Processing Record 20 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 21 of Set 1 | tilichiki
# Processing Record 22 of Set 1 | dali
# Processing Record 23 of Set 1 | lebu
# Processing Record 24 of Set 1 | ushuaia
# Processing Record 25 of Set 1 | sarkand
# Processing Record 26 of Set 1 | castro
# Processing Record 27 of Set 1 | ningxiang
# Processing Record 28 of Set 1 | adrar
# Processing Record 29 of Set 1 | chokurdakh
# Processing Record 30 of Set 1 | esperance
# Processing Record 31 of Set 1 | nguiu
# City not found. Skipping...
# Processing Record 32 of Set 1 | mamontovo
# Processing Record 33 of Set 1 | ormara
# Processing Record 34 of Set 1 | teguldet
# Processing Record 35 of Set 1 | provideniya
# Processing Record 36 of Set 1 | nioro
# Processing Record 37 of Set 1 | puerto escondido
# Processing Record 38 of Set 1 | punta arenas
# Processing Record 39 of Set 1 | vaini
# Processing Record 40 of Set 1 | alice springs
# Processing Record 41 of Set 1 | severnyy
# Processing Record 42 of Set 1 | atuona
# Processing Record 43 of Set 1 | sao jose da coroa grande
# Processing Record 44 of Set 1 | tarudant
# City not found. Skipping...
# Processing Record 45 of Set 1 | avarua
# Processing Record 46 of Set 1 | caldas novas
# Processing Record 47 of Set 1 | maceio
# Processing Record 48 of Set 1 | jamestown
# Processing Record 49 of Set 1 | saskylakh
# Processing Record 50 of Set 1 | klaksvik
# Processing Record 1 of Set 2 | bonnyville
# Processing Record 2 of Set 2 | tuktoyaktuk
# Processing Record 3 of Set 2 | mugur-aksy
# Processing Record 4 of Set 2 | belomorsk
# Processing Record 5 of Set 2 | grindavik
# Processing Record 6 of Set 2 | barrow
# Processing Record 7 of Set 2 | verkhnetulomskiy
# Processing Record 8 of Set 2 | benguela
# Processing Record 9 of Set 2 | port alfred
# Processing Record 10 of Set 2 | cape town
# Processing Record 11 of Set 2 | fairbanks
# Processing Record 12 of Set 2 | kungurtug
# Processing Record 13 of Set 2 | okhotsk
# Processing Record 14 of Set 2 | bredasdorp
# Processing Record 15 of Set 2 | yellowknife
# Processing Record 16 of Set 2 | rockhampton
# Processing Record 17 of Set 2 | goya
# Processing Record 18 of Set 2 | east london
# Processing Record 19 of Set 2 | dicabisagan
# Processing Record 20 of Set 2 | dekoa
# City not found. Skipping...
# Processing Record 21 of Set 2 | constitucion
# Processing Record 22 of Set 2 | sitka
# Processing Record 23 of Set 2 | wattegama
# Processing Record 24 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 2 | bluff
# Processing Record 26 of Set 2 | chuy
# Processing Record 27 of Set 2 | rantepao
# Processing Record 28 of Set 2 | itoman
# Processing Record 29 of Set 2 | puerto ayora
# Processing Record 30 of Set 2 | kavieng
# Processing Record 31 of Set 2 | boa vista
# Processing Record 32 of Set 2 | davenda
# Processing Record 33 of Set 2 | bathsheba
# Processing Record 34 of Set 2 | hami
# Processing Record 35 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 36 of Set 2 | katangli
# Processing Record 37 of Set 2 | naberera
# Processing Record 38 of Set 2 | lerwick
# Processing Record 39 of Set 2 | lorengau
# Processing Record 40 of Set 2 | arraial do cabo
# Processing Record 41 of Set 2 | hofn
# Processing Record 42 of Set 2 | susangerd
# Processing Record 43 of Set 2 | georgetown
# Processing Record 44 of Set 2 | aksarka
# Processing Record 45 of Set 2 | beloha
# Processing Record 46 of Set 2 | husavik
# Processing Record 47 of Set 2 | mangai
# Processing Record 48 of Set 2 | okha
# Processing Record 49 of Set 2 | copiapo
# Processing Record 50 of Set 2 | new norfolk
# Processing Record 1 of Set 3 | hithadhoo
# Processing Record 2 of Set 3 | sopelana
# Processing Record 3 of Set 3 | auki
# Processing Record 4 of Set 3 | nikolskoye
# Processing Record 5 of Set 3 | poum
# Processing Record 6 of Set 3 | kelheim
# Processing Record 7 of Set 3 | kohlu
# Processing Record 8 of Set 3 | sao filipe
# Processing Record 9 of Set 3 | iskateley
# Processing Record 10 of Set 3 | butaritari
# Processing Record 11 of Set 3 | tiznit
# Processing Record 12 of Set 3 | ribeira grande
# Processing Record 13 of Set 3 | ahipara
# Processing Record 14 of Set 3 | zuwarah
# Processing Record 15 of Set 3 | tromso
# Processing Record 16 of Set 3 | sumbawanga
# Processing Record 17 of Set 3 | pafos
# Processing Record 18 of Set 3 | saint-philippe
# Processing Record 19 of Set 3 | plettenberg bay
# Processing Record 20 of Set 3 | sapa
# Processing Record 21 of Set 3 | strezhevoy
# Processing Record 22 of Set 3 | busselton
# Processing Record 23 of Set 3 | dikson
# Processing Record 24 of Set 3 | serenje
# Processing Record 25 of Set 3 | margate
# Processing Record 26 of Set 3 | brae
# Processing Record 27 of Set 3 | lompoc
# Processing Record 28 of Set 3 | cockburn town
# Processing Record 29 of Set 3 | ponta do sol
# Processing Record 30 of Set 3 | vila franca do campo
# Processing Record 31 of Set 3 | srivardhan
# Processing Record 32 of Set 3 | tasiilaq
# Processing Record 33 of Set 3 | pau brasil
# Processing Record 34 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 35 of Set 3 | ekhabi
# Processing Record 36 of Set 3 | chirongui
# Processing Record 37 of Set 3 | roald
# Processing Record 38 of Set 3 | kaitangata
# Processing Record 39 of Set 3 | mongoumba
# Processing Record 40 of Set 3 | nhulunbuy
# Processing Record 41 of Set 3 | panaba
# Processing Record 42 of Set 3 | mandera
# Processing Record 43 of Set 3 | tagbac
# Processing Record 44 of Set 3 | bambous virieux
# Processing Record 45 of Set 3 | znamenskoye
# Processing Record 46 of Set 3 | mehamn
# Processing Record 47 of Set 3 | hermanus
# Processing Record 48 of Set 3 | sedan
# Processing Record 49 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 50 of Set 3 | cherskiy
# Processing Record 1 of Set 4 | burica
# City not found. Skipping...
# Processing Record 2 of Set 4 | providencia
# Processing Record 3 of Set 4 | touros
# Processing Record 4 of Set 4 | awjilah
# Processing Record 5 of Set 4 | yulara
# Processing Record 6 of Set 4 | hasaki
# Processing Record 7 of Set 4 | thinadhoo
# Processing Record 8 of Set 4 | tevriz
# Processing Record 9 of Set 4 | ust-nera
# Processing Record 10 of Set 4 | lata
# Processing Record 11 of Set 4 | fortuna
# Processing Record 12 of Set 4 | mahibadhoo
# Processing Record 13 of Set 4 | alugan
# Processing Record 14 of Set 4 | upernavik
# Processing Record 15 of Set 4 | severo-kurilsk
# Processing Record 16 of Set 4 | nanortalik
# Processing Record 17 of Set 4 | mabaruma
# Processing Record 18 of Set 4 | nyagan
# Processing Record 19 of Set 4 | guerrero negro
# Processing Record 20 of Set 4 | vardo
# Processing Record 21 of Set 4 | namibe
# Processing Record 22 of Set 4 | inirida
# Processing Record 23 of Set 4 | puerto leguizamo
# Processing Record 24 of Set 4 | praia da vitoria
# Processing Record 25 of Set 4 | galiwinku
# City not found. Skipping...
# Processing Record 26 of Set 4 | zhoukou
# Processing Record 27 of Set 4 | mahebourg
# Processing Record 28 of Set 4 | iqaluit
# Processing Record 29 of Set 4 | berlevag
# Processing Record 30 of Set 4 | mount gambier
# Processing Record 31 of Set 4 | cidreira
# Processing Record 32 of Set 4 | vao
# Processing Record 33 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 34 of Set 4 | ilulissat
# Processing Record 35 of Set 4 | kathu
# Processing Record 36 of Set 4 | nome
# Processing Record 37 of Set 4 | launceston
# Processing Record 38 of Set 4 | pomoryany
# Processing Record 39 of Set 4 | manokwari
# Processing Record 40 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 41 of Set 4 | talnakh
# Processing Record 42 of Set 4 | kazachinskoye
# Processing Record 43 of Set 4 | zanatepec
# City not found. Skipping...
# Processing Record 44 of Set 4 | santa fe
# Processing Record 45 of Set 4 | ipixuna
# Processing Record 46 of Set 4 | libreville
# Processing Record 47 of Set 4 | torbay
# Processing Record 48 of Set 4 | ilhabela
# Processing Record 49 of Set 4 | isangel
# Processing Record 50 of Set 4 | dongsheng
# Processing Record 1 of Set 5 | fort nelson
# Processing Record 2 of Set 5 | chhatarpur
# Processing Record 3 of Set 5 | rio gallegos
# Processing Record 4 of Set 5 | haines junction
# Processing Record 5 of Set 5 | victoria
# Processing Record 6 of Set 5 | sorland
# Processing Record 7 of Set 5 | salaga
# Processing Record 8 of Set 5 | airai
# Processing Record 9 of Set 5 | kartaly
# Processing Record 10 of Set 5 | bac lieu
# Processing Record 11 of Set 5 | kahului
# Processing Record 12 of Set 5 | piltene
# Processing Record 13 of Set 5 | kropotkin
# Processing Record 14 of Set 5 | tubuala
# Processing Record 15 of Set 5 | marsh harbour
# Processing Record 16 of Set 5 | kathmandu
# Processing Record 17 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 18 of Set 5 | amapa
# Processing Record 19 of Set 5 | qaanaaq
# Processing Record 20 of Set 5 | peddapalli
# Processing Record 21 of Set 5 | maragogi
# Processing Record 22 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 23 of Set 5 | kalabo
# Processing Record 24 of Set 5 | port elizabeth
# Processing Record 25 of Set 5 | ambanja
# Processing Record 26 of Set 5 | mar del plata
# Processing Record 27 of Set 5 | bethel
# Processing Record 28 of Set 5 | bacungan
# Processing Record 29 of Set 5 | half moon bay
# Processing Record 30 of Set 5 | aklavik
# Processing Record 31 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 5 | carnarvon
# Processing Record 33 of Set 5 | bandarbeyla
# Processing Record 34 of Set 5 | faanui
# Processing Record 35 of Set 5 | zhigansk
# Processing Record 36 of Set 5 | quelimane
# Processing Record 37 of Set 5 | port hardy
# Processing Record 38 of Set 5 | alofi
# Processing Record 39 of Set 5 | palmer
# Processing Record 40 of Set 5 | biratnagar
# Processing Record 41 of Set 5 | baghdad
# Processing Record 42 of Set 5 | broken hill
# Processing Record 43 of Set 5 | ust-ishim
# Processing Record 44 of Set 5 | san jose de rio tinto
# Processing Record 45 of Set 5 | vila velha
# Processing Record 46 of Set 5 | kerman
# Processing Record 47 of Set 5 | vilyuysk
# Processing Record 48 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 49 of Set 5 | gurupi
# Processing Record 50 of Set 5 | san martin
# Processing Record 1 of Set 6 | gunjur
# Processing Record 2 of Set 6 | svetlaya
# Processing Record 3 of Set 6 | iraquara
# Processing Record 4 of Set 6 | muros
# Processing Record 5 of Set 6 | pisco
# Processing Record 6 of Set 6 | porto novo
# Processing Record 7 of Set 6 | kushiro
# Processing Record 8 of Set 6 | bubaque
# Processing Record 9 of Set 6 | saldanha
# Processing Record 10 of Set 6 | asau
# Processing Record 11 of Set 6 | tautira
# Processing Record 12 of Set 6 | ancud
# Processing Record 13 of Set 6 | trapani
# Processing Record 14 of Set 6 | taoudenni
# Processing Record 15 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 16 of Set 6 | wanning
# Processing Record 17 of Set 6 | clyde river
# Processing Record 18 of Set 6 | takoradi
# Processing Record 19 of Set 6 | coquimbo
# Processing Record 20 of Set 6 | pevek
# Processing Record 21 of Set 6 | burnie
# Processing Record 22 of Set 6 | bengkulu
# Processing Record 23 of Set 6 | wendelstein
# Processing Record 24 of Set 6 | yurty
# Processing Record 25 of Set 6 | pitimbu
# Processing Record 26 of Set 6 | curvelo
# Processing Record 27 of Set 6 | tabuk
# Processing Record 28 of Set 6 | udachnyy
# Processing Record 29 of Set 6 | yumen
# Processing Record 30 of Set 6 | bulgan
# Processing Record 31 of Set 6 | moses lake
# Processing Record 32 of Set 6 | geraldton
# Processing Record 33 of Set 6 | karratha
# Processing Record 34 of Set 6 | kralendijk
# Processing Record 35 of Set 6 | dzhusaly
# City not found. Skipping...
# Processing Record 36 of Set 6 | henties bay
# Processing Record 37 of Set 6 | sokolo
# Processing Record 38 of Set 6 | filingue
# Processing Record 39 of Set 6 | gladstone
# Processing Record 40 of Set 6 | turkistan
# Processing Record 41 of Set 6 | vestmannaeyjar
# Processing Record 42 of Set 6 | avera
# Processing Record 43 of Set 6 | victor harbor
# Processing Record 44 of Set 6 | honiara
# Processing Record 45 of Set 6 | inderborskiy
# City not found. Skipping...
# Processing Record 46 of Set 6 | magadi
# Processing Record 47 of Set 6 | macheng
# Processing Record 48 of Set 6 | richards bay
# Processing Record 49 of Set 6 | bojnurd
# Processing Record 50 of Set 6 | viedma
# Processing Record 1 of Set 7 | ballina
# Processing Record 2 of Set 7 | bur gabo
# City not found. Skipping...
# Processing Record 3 of Set 7 | dunedin
# Processing Record 4 of Set 7 | kadarkut
# Processing Record 5 of Set 7 | puerto del rosario
# Processing Record 6 of Set 7 | pangnirtung
# Processing Record 7 of Set 7 | seymchan
# Processing Record 8 of Set 7 | barsovo
# Processing Record 9 of Set 7 | key west
# Processing Record 10 of Set 7 | ust-koksa
# Processing Record 11 of Set 7 | ostrovnoy
# Processing Record 12 of Set 7 | tondano
# Processing Record 13 of Set 7 | kaiyuan
# Processing Record 14 of Set 7 | urengoy
# Processing Record 15 of Set 7 | paracuru
# Processing Record 16 of Set 7 | qasigiannguit
# Processing Record 17 of Set 7 | rocha
# Processing Record 18 of Set 7 | nador
# Processing Record 19 of Set 7 | salisbury
# Processing Record 20 of Set 7 | aykhal
# Processing Record 21 of Set 7 | pozo colorado
# Processing Record 22 of Set 7 | denpasar
# Processing Record 23 of Set 7 | waingapu
# Processing Record 24 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 25 of Set 7 | macaboboni
# City not found. Skipping...
# Processing Record 26 of Set 7 | marzuq
# Processing Record 27 of Set 7 | hoquiam
# Processing Record 28 of Set 7 | coihaique
# Processing Record 29 of Set 7 | thompson
# Processing Record 30 of Set 7 | humaita
# Processing Record 31 of Set 7 | kovur
# Processing Record 32 of Set 7 | kloulklubed
# Processing Record 33 of Set 7 | atambua
# Processing Record 34 of Set 7 | astoria
# Processing Record 35 of Set 7 | homer
# Processing Record 36 of Set 7 | opobo
# City not found. Skipping...
# Processing Record 37 of Set 7 | sterling
# Processing Record 38 of Set 7 | codrington
# Processing Record 39 of Set 7 | lewiston
# Processing Record 40 of Set 7 | jinji
# Processing Record 41 of Set 7 | khatanga
# Processing Record 42 of Set 7 | tateyama
# Processing Record 43 of Set 7 | ati
# Processing Record 44 of Set 7 | naze
# Processing Record 45 of Set 7 | sivaki
# Processing Record 46 of Set 7 | vanimo
# Processing Record 47 of Set 7 | laguna
# Processing Record 48 of Set 7 | makung
# City not found. Skipping...
# Processing Record 49 of Set 7 | birobidzhan
# Processing Record 50 of Set 7 | dongli
# Processing Record 1 of Set 8 | nishihara
# Processing Record 2 of Set 8 | alibunar
# Processing Record 3 of Set 8 | necochea
# Processing Record 4 of Set 8 | tiksi
# Processing Record 5 of Set 8 | foundiougne
# Processing Record 6 of Set 8 | saint-pierre
# Processing Record 7 of Set 8 | tanabe
# Processing Record 8 of Set 8 | santo antonio do ica
# Processing Record 9 of Set 8 | belaya
# Processing Record 10 of Set 8 | greece
# Processing Record 11 of Set 8 | arenzano
# Processing Record 12 of Set 8 | dingle
# Processing Record 13 of Set 8 | natal
# Processing Record 14 of Set 8 | hambantota
# Processing Record 15 of Set 8 | pratapgarh
# Processing Record 16 of Set 8 | san luis
# Processing Record 17 of Set 8 | kirensk
# Processing Record 18 of Set 8 | bitung
# Processing Record 19 of Set 8 | belaya gora
# Processing Record 20 of Set 8 | kayes
# Processing Record 21 of Set 8 | hobyo
# Processing Record 22 of Set 8 | tiarei
# Processing Record 23 of Set 8 | uttarkashi
# Processing Record 24 of Set 8 | lasa
# Processing Record 25 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 26 of Set 8 | meulaboh
# Processing Record 27 of Set 8 | dois corregos
# Processing Record 28 of Set 8 | inhambane
# Processing Record 29 of Set 8 | longyearbyen
# Processing Record 30 of Set 8 | marihatag
# Processing Record 31 of Set 8 | kodiak
# Processing Record 32 of Set 8 | slonim
# Processing Record 33 of Set 8 | shimoda
# Processing Record 34 of Set 8 | etla
# Processing Record 35 of Set 8 | ostersund
# Processing Record 36 of Set 8 | rostovka
# Processing Record 37 of Set 8 | bakchar
# Processing Record 38 of Set 8 | hwange
# Processing Record 39 of Set 8 | plouzane
# Processing Record 40 of Set 8 | evanston
# Processing Record 41 of Set 8 | marienburg
# Processing Record 42 of Set 8 | sistranda
# Processing Record 43 of Set 8 | ketchikan
# Processing Record 44 of Set 8 | norman wells
# Processing Record 45 of Set 8 | kununurra
# Processing Record 46 of Set 8 | zhangye
# Processing Record 47 of Set 8 | cobija
# Processing Record 48 of Set 8 | larsnes
# Processing Record 49 of Set 8 | rokytne
# Processing Record 50 of Set 8 | tommot
# Processing Record 1 of Set 9 | senador jose porfirio
# Processing Record 2 of Set 9 | rassvet
# Processing Record 3 of Set 9 | oktyabrskiy
# Processing Record 4 of Set 9 | port macquarie
# Processing Record 5 of Set 9 | lavrentiya
# Processing Record 6 of Set 9 | kalispell
# Processing Record 7 of Set 9 | turukhansk
# Processing Record 8 of Set 9 | chimbote
# Processing Record 9 of Set 9 | puerto penasco
# Processing Record 10 of Set 9 | mineiros
# Processing Record 11 of Set 9 | ananas
# Processing Record 12 of Set 9 | cabedelo
# Processing Record 13 of Set 9 | smidovich
# Processing Record 14 of Set 9 | goderich
# Processing Record 15 of Set 9 | nuuk
# Processing Record 16 of Set 9 | liverpool
# Processing Record 17 of Set 9 | saint-francois
# Processing Record 18 of Set 9 | alyangula
# Processing Record 19 of Set 9 | egvekinot
# Processing Record 20 of Set 9 | vagay
# Processing Record 21 of Set 9 | ponta delgada
# Processing Record 22 of Set 9 | togitsu
# Processing Record 23 of Set 9 | kruisfontein
# Processing Record 24 of Set 9 | faya
# Processing Record 25 of Set 9 | paddhari
# Processing Record 26 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 27 of Set 9 | kahramanmaras
# Processing Record 28 of Set 9 | shelburne
# Processing Record 29 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 30 of Set 9 | trofaiach
# Processing Record 31 of Set 9 | katsuura
# Processing Record 32 of Set 9 | kasongo-lunda
# Processing Record 33 of Set 9 | panjwin
# City not found. Skipping...
# Processing Record 34 of Set 9 | yerbogachen
# Processing Record 35 of Set 9 | athabasca
# Processing Record 36 of Set 9 | mayo
# Processing Record 37 of Set 9 | george town
# Processing Record 38 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 39 of Set 9 | wufeng
# Processing Record 40 of Set 9 | manjacaze
# Processing Record 41 of Set 9 | acarau
# Processing Record 42 of Set 9 | petatlan
# Processing Record 43 of Set 9 | am timan
# Processing Record 44 of Set 9 | neuquen
# Processing Record 45 of Set 9 | northam
# Processing Record 46 of Set 9 | nouadhibou
# Processing Record 47 of Set 9 | itarema
# Processing Record 48 of Set 9 | kabo
# Processing Record 49 of Set 9 | ratnagiri
# Processing Record 50 of Set 9 | cururupu
# Processing Record 1 of Set 10 | manado
# Processing Record 2 of Set 10 | skagastrond
# City not found. Skipping...
# Processing Record 3 of Set 10 | salta
# Processing Record 4 of Set 10 | narsaq
# Processing Record 5 of Set 10 | puerto baquerizo moreno
# Processing Record 6 of Set 10 | san cristobal
# Processing Record 7 of Set 10 | povenets
# Processing Record 8 of Set 10 | nchelenge
# Processing Record 9 of Set 10 | naron
# Processing Record 10 of Set 10 | san vicente
# Processing Record 11 of Set 10 | hit
# Processing Record 12 of Set 10 | malayal
# Processing Record 13 of Set 10 | novikovo
# Processing Record 14 of Set 10 | dubbo
# Processing Record 15 of Set 10 | cayenne
# Processing Record 16 of Set 10 | tuatapere
# Processing Record 17 of Set 10 | keetmanshoop
# Processing Record 18 of Set 10 | san jeronimo
# Processing Record 19 of Set 10 | suwannaphum
# Processing Record 20 of Set 10 | acapulco
# Processing Record 21 of Set 10 | douglas
# Processing Record 22 of Set 10 | matara
# Processing Record 23 of Set 10 | coxim
# Processing Record 24 of Set 10 | kimbe
# Processing Record 25 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 26 of Set 10 | taloqan
# Processing Record 27 of Set 10 | la ronge
# Processing Record 28 of Set 10 | springbok
# Processing Record 29 of Set 10 | los llanos de aridane
# Processing Record 30 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 31 of Set 10 | andenes
# Processing Record 32 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 33 of Set 10 | panzhihua
# Processing Record 34 of Set 10 | ogulin
# Processing Record 35 of Set 10 | college
# Processing Record 36 of Set 10 | nemuro
# Processing Record 37 of Set 10 | samarai
# Processing Record 38 of Set 10 | antalaha
# Processing Record 39 of Set 10 | progreso
# Processing Record 40 of Set 10 | caernarfon
# Processing Record 41 of Set 10 | coahuayana
# Processing Record 42 of Set 10 | leningradskiy
# Processing Record 43 of Set 10 | roma
# Processing Record 44 of Set 10 | kegayli
# City not found. Skipping...
# Processing Record 45 of Set 10 | yarim
# Processing Record 46 of Set 10 | the valley
# Processing Record 47 of Set 10 | borogontsy
# Processing Record 48 of Set 10 | vadso
# Processing Record 49 of Set 10 | bairnsdale
# Processing Record 50 of Set 10 | nha trang
# Processing Record 1 of Set 11 | mokhsogollokh
# Processing Record 2 of Set 11 | belmonte
# Processing Record 3 of Set 11 | ixtepec
# Processing Record 4 of Set 11 | formosa
# Processing Record 5 of Set 11 | prince rupert
# Processing Record 6 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 7 of Set 11 | gat
# Processing Record 8 of Set 11 | quatre cocos
# Processing Record 9 of Set 11 | yeppoon
# Processing Record 10 of Set 11 | luohe
# Processing Record 11 of Set 11 | grand gaube
# Processing Record 12 of Set 11 | songjianghe
# Processing Record 13 of Set 11 | novocheremshansk
# Processing Record 14 of Set 11 | san ignacio
# Processing Record 15 of Set 11 | darhan
# Processing Record 16 of Set 11 | port blair
# Processing Record 17 of Set 11 | cabo rojo
# Processing Record 18 of Set 11 | haibowan
# City not found. Skipping...
# Processing Record 19 of Set 11 | bababe
# City not found. Skipping...
# Processing Record 20 of Set 11 | goma
# Processing Record 21 of Set 11 | mount isa
# Processing Record 22 of Set 11 | burgeo
# Processing Record 23 of Set 11 | portland
# Processing Record 24 of Set 11 | cruzeiro do sul
# Processing Record 25 of Set 11 | lexington park
# Processing Record 26 of Set 11 | rio cuarto
# Processing Record 27 of Set 11 | emerald
# Processing Record 28 of Set 11 | verkh-usugli
# Processing Record 29 of Set 11 | rosetta
# Processing Record 30 of Set 11 | tual
# Processing Record 31 of Set 11 | sharlyk
# Processing Record 32 of Set 11 | erzin
# Processing Record 33 of Set 11 | stornoway
# Processing Record 34 of Set 11 | cassano delle murge
# Processing Record 35 of Set 11 | san matias
# Processing Record 36 of Set 11 | kautokeino
# Processing Record 37 of Set 11 | zhangjiakou
# Processing Record 38 of Set 11 | coshocton
# Processing Record 39 of Set 11 | goure
# Processing Record 40 of Set 11 | boatlaname
# City not found. Skipping...
# Processing Record 41 of Set 11 | lansing
# Processing Record 42 of Set 11 | kavaratti
# Processing Record 43 of Set 11 | vitim
# Processing Record 44 of Set 11 | mareeba
# Processing Record 45 of Set 11 | salinopolis
# Processing Record 46 of Set 11 | marandahalli
# Processing Record 47 of Set 11 | bom jesus da lapa
# Processing Record 48 of Set 11 | scottsburgh
# City not found. Skipping...
# Processing Record 49 of Set 11 | harbour breton
# Processing Record 50 of Set 11 | kangaba
# Processing Record 1 of Set 12 | port keats
# Processing Record 2 of Set 12 | amboasary
# Processing Record 3 of Set 12 | jalu
# Processing Record 4 of Set 12 | baherden
# Processing Record 5 of Set 12 | bulaevo
# Processing Record 6 of Set 12 | belyy yar
# Processing Record 7 of Set 12 | bondo
# Processing Record 8 of Set 12 | macae
# Processing Record 9 of Set 12 | bontang
# Processing Record 10 of Set 12 | wawa
# Processing Record 11 of Set 12 | olivehurst
# Processing Record 12 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 13 of Set 12 | labutta
# City not found. Skipping...
# Processing Record 14 of Set 12 | mitsamiouli
# Processing Record 15 of Set 12 | drayton valley
# Processing Record 16 of Set 12 | erenhot
# Processing Record 17 of Set 12 | ingham
# Processing Record 18 of Set 12 | saint george
# Processing Record 19 of Set 12 | tabialan
# City not found. Skipping...
# Processing Record 20 of Set 12 | zhaotong
# Processing Record 21 of Set 12 | vicente guerrero
# Processing Record 22 of Set 12 | anori
# Processing Record 23 of Set 12 | roberval
# Processing Record 24 of Set 12 | nago
# Processing Record 25 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 26 of Set 12 | kabansk
# Processing Record 27 of Set 12 | abu dhabi
# Processing Record 28 of Set 12 | mikkeli
# Processing Record 29 of Set 12 | richmond
# Processing Record 30 of Set 12 | zeya
# Processing Record 31 of Set 12 | hauterive
# Processing Record 32 of Set 12 | umm kaddadah
# Processing Record 33 of Set 12 | mangrol
# Processing Record 34 of Set 12 | camacha
# Processing Record 35 of Set 12 | lewistown
# Processing Record 36 of Set 12 | gumdag
# Processing Record 37 of Set 12 | beirut
# Processing Record 38 of Set 12 | rongcheng
# Processing Record 39 of Set 12 | pitsunda
# Processing Record 40 of Set 12 | altamira
# Processing Record 41 of Set 12 | barzas
# Processing Record 42 of Set 12 | alghero
# Processing Record 43 of Set 12 | balaka
# Processing Record 44 of Set 12 | chincha alta
# Processing Record 45 of Set 12 | kolomna
# Processing Record 46 of Set 12 | te anau
# Processing Record 47 of Set 12 | komsomolskiy
# Processing Record 48 of Set 12 | nisia floresta
# Processing Record 49 of Set 12 | marsa matruh
# Processing Record 50 of Set 12 | kalaleh
# Processing Record 1 of Set 13 | huarmey
# Processing Record 2 of Set 13 | barraute
# Processing Record 3 of Set 13 | ise
# Processing Record 4 of Set 13 | makeni
# Processing Record 5 of Set 13 | coldstream
# Processing Record 6 of Set 13 | colon
# Processing Record 7 of Set 13 | maridi
# Processing Record 8 of Set 13 | pacific grove
# Processing Record 9 of Set 13 | deputatskiy
# Processing Record 10 of Set 13 | srednekolymsk
# Processing Record 11 of Set 13 | cabo san lucas
# Processing Record 12 of Set 13 | acajutla
# Processing Record 13 of Set 13 | xichang
# Processing Record 14 of Set 13 | bayan
# Processing Record 15 of Set 13 | myitkyina
# Processing Record 16 of Set 13 | kilrush
# Processing Record 17 of Set 13 | cefalu
# Processing Record 18 of Set 13 | chestermere
# Processing Record 19 of Set 13 | zyryanskoye
# Processing Record 20 of Set 13 | narbonne
# Processing Record 21 of Set 13 | beringovskiy
# Processing Record 22 of Set 13 | huazolotitlan
# City not found. Skipping...
# Processing Record 23 of Set 13 | uglovskoye
# Processing Record 24 of Set 13 | wukari
# Processing Record 25 of Set 13 | hihifo
# City not found. Skipping...
# Processing Record 26 of Set 13 | safwah
# City not found. Skipping...
# Processing Record 27 of Set 13 | gorontalo
# Processing Record 28 of Set 13 | pansoy
# Processing Record 29 of Set 13 | batticaloa
# Processing Record 30 of Set 13 | zyryanka
# Processing Record 31 of Set 13 | makasar
# Processing Record 32 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 33 of Set 13 | tottori
# Processing Record 34 of Set 13 | jiuquan
# Processing Record 35 of Set 13 | delta
# Processing Record 36 of Set 13 | akyab
# Processing Record 37 of Set 13 | amuntai
# Processing Record 38 of Set 13 | miri
# Processing Record 39 of Set 13 | santona
# Processing Record 40 of Set 13 | flinders
# Processing Record 41 of Set 13 | santiago del estero
# Processing Record 42 of Set 13 | presidente dutra
# Processing Record 43 of Set 13 | assens
# Processing Record 44 of Set 13 | kupang
# Processing Record 45 of Set 13 | las vegas
# Processing Record 46 of Set 13 | umm lajj
# Processing Record 47 of Set 13 | gabu
# Processing Record 48 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 49 of Set 13 | khartoum
# Processing Record 50 of Set 13 | cravo norte
# Processing Record 1 of Set 14 | christchurch
# Processing Record 2 of Set 14 | aflu
# City not found. Skipping...
# Processing Record 3 of Set 14 | barcelos
# Processing Record 4 of Set 14 | rio grande
# Processing Record 5 of Set 14 | tourlaville
# Processing Record 6 of Set 14 | teya
# Processing Record 7 of Set 14 | manacapuru
# Processing Record 8 of Set 14 | andra
# Processing Record 9 of Set 14 | gotsu
# Processing Record 10 of Set 14 | sao felix do xingu
# Processing Record 11 of Set 14 | surgut
# Processing Record 12 of Set 14 | kurumkan
# Processing Record 13 of Set 14 | banyo
# Processing Record 14 of Set 14 | port-gentil
# Processing Record 15 of Set 14 | karakose
# City not found. Skipping...
# Processing Record 16 of Set 14 | high level
# Processing Record 17 of Set 14 | cienfuegos
# Processing Record 18 of Set 14 | paraiso
# Processing Record 19 of Set 14 | pizhanka
# Processing Record 20 of Set 14 | urumqi
# Processing Record 21 of Set 14 | sainte-anne-des-monts
# Processing Record 22 of Set 14 | kisangani
# Processing Record 23 of Set 14 | tornio
# Processing Record 24 of Set 14 | limoeiro do norte
# Processing Record 25 of Set 14 | ossora
# Processing Record 26 of Set 14 | yenagoa
# Processing Record 27 of Set 14 | arshan
# Processing Record 28 of Set 14 | port hawkesbury
# Processing Record 29 of Set 14 | banepa
# Processing Record 30 of Set 14 | atasu
# Processing Record 31 of Set 14 | nitra
# Processing Record 32 of Set 14 | pangody
# Processing Record 33 of Set 14 | jiancheng
# Processing Record 34 of Set 14 | kidal
# Processing Record 35 of Set 14 | manubah
# City not found. Skipping...
# Processing Record 36 of Set 14 | winnemucca
# Processing Record 37 of Set 14 | adre
# Processing Record 38 of Set 14 | nabire
# Processing Record 39 of Set 14 | sukumo
# Processing Record 40 of Set 14 | rybachiy
# Processing Record 41 of Set 14 | panelas
# Processing Record 42 of Set 14 | lagoa
# Processing Record 43 of Set 14 | namatanai
# Processing Record 44 of Set 14 | kitimat
# Processing Record 45 of Set 14 | eureka
# Processing Record 46 of Set 14 | kokoda
# Processing Record 47 of Set 14 | herat
# Processing Record 48 of Set 14 | sayanogorsk
# Processing Record 49 of Set 14 | birin
# Processing Record 50 of Set 14 | eyl
# Processing Record 1 of Set 15 | hay river
# Processing Record 2 of Set 15 | axim
# Processing Record 3 of Set 15 | sharan
# Processing Record 4 of Set 15 | shakawe
# Processing Record 5 of Set 15 | san patricio
# Processing Record 6 of Set 15 | luganville
# Processing Record 7 of Set 15 | andria
# Processing Record 8 of Set 15 | lima
# Processing Record 9 of Set 15 | phan thiet
# Processing Record 10 of Set 15 | aloleng
# Processing Record 11 of Set 15 | chapais
# Processing Record 12 of Set 15 | sangar
# Processing Record 13 of Set 15 | melton
# Processing Record 14 of Set 15 | palu
# Processing Record 15 of Set 15 | ulaangom
# Processing Record 16 of Set 15 | kishorganj
# Processing Record 17 of Set 15 | gamba
# Processing Record 18 of Set 15 | khasan
# Processing Record 19 of Set 15 | canitas
# City not found. Skipping...
# Processing Record 20 of Set 15 | plerin
# Processing Record 21 of Set 15 | charters towers
# Processing Record 22 of Set 15 | chettipalaiyam
# Processing Record 23 of Set 15 | paamiut
# Processing Record 24 of Set 15 | viamao
# Processing Record 25 of Set 15 | tukrah
# Processing Record 26 of Set 15 | colares
# Processing Record 27 of Set 15 | goundam
# Processing Record 28 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 29 of Set 15 | nobres
# Processing Record 30 of Set 15 | bayanday
# Processing Record 31 of Set 15 | maholi
# Processing Record 32 of Set 15 | longlac
# City not found. Skipping...
# Processing Record 33 of Set 15 | devonport
# Processing Record 34 of Set 15 | kazalinsk
# City not found. Skipping...
# Processing Record 35 of Set 15 | alta floresta
# Processing Record 36 of Set 15 | vilhena
# Processing Record 37 of Set 15 | shahgarh
# Processing Record 38 of Set 15 | shu
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 680

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Aasiaat  68.7098  -52.8699     33.51        99         100
# 1     Pemberton  50.3164 -122.8027     77.20        31          17
# 2  Poplar Bluff  36.7570  -90.3929     55.29        27           0
# 3      Yar-Sale  66.8333   70.8333     39.65        94         100
# 4        Albany  42.6001  -73.9662     55.89        63          76
# 5      Souillac -20.5167   57.5167     70.18        73          20
# 6      Pechenga  69.5259   31.1703     36.63        95          79
# 7          Hilo  19.7297 -155.0900     90.28        69           0
# 8        Ryotsu  38.0833  138.4333     52.88        56          25
# 9       Rikitea -23.1203 -134.9692     68.83        62           0
#
#    Wind Speed Country Current Description
# 0        7.02      GL                snow
# 1        2.71      CA          few clouds
# 2       11.50      US           clear sky
# 3       13.65      RU     overcast clouds
# 4        8.63      US       broken clouds
# 5       10.36      MU          few clouds
# 6       18.57      RU       broken clouds
# 7        8.05      US           clear sky
# 8        6.17      JP    scattered clouds
# 9       19.01      PF           clear sky

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
reorder_weather_data = ["City", "Country", "Lat","Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[reorder_weather_data]
# Display sample data
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Aasiaat      GL  68.7098  -52.8699     33.51        99         100
# 1     Pemberton      CA  50.3164 -122.8027     77.20        31          17
# 2  Poplar Bluff      US  36.7570  -90.3929     55.29        27           0
# 3      Yar-Sale      RU  66.8333   70.8333     39.65        94         100
# 4        Albany      US  42.6001  -73.9662     55.89        63          76
# 5      Souillac      MU -20.5167   57.5167     70.18        73          20
# 6      Pechenga      RU  69.5259   31.1703     36.63        95          79
# 7          Hilo      US  19.7297 -155.0900     90.28        69           0
# 8        Ryotsu      JP  38.0833  138.4333     52.88        56          25
# 9       Rikitea      PF -23.1203 -134.9692     68.83        62           0
#
#    Wind Speed Current Description
# 0        7.02                snow
# 1        2.71          few clouds
# 2       11.50           clear sky
# 3       13.65     overcast clouds
# 4        8.63       broken clouds
# 5       10.36          few clouds
# 6       18.57       broken clouds
# 7        8.05           clear sky
# 8        6.17    scattered clouds
# 9       19.01           clear sky

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
